# %%
from random import shuffle

# %%
suits = ('hearts','diamonds','spades','clubs')
ranks = ('two','three','four','five','six','seven','eight','nine','ten','jack','queen','king','ace')

values = { 'two' : 2 , 'three' : 3 , 'four' : 4 , 'five' : 5, 'six' : 6 , 'seven' : 7 , 'eight' : 8 , 'nine' : 9 ,
           'ten' : 10 , 'jack' : 11 , 'queen' : 12 , 'king' : 13 , 'ace' : 14 }

# %%
class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + ' of ' + self.suit

# %%
class Deck:
    def __init__(self):
        
        self.cards = []
        
        for i in range(len(suits)):
            for j in range(len(ranks)):
                self.cards.append(Card(suits[i],ranks[j]))
    
    def __str__(self):
        text = ''
        for i in range(len(self.cards)):
            text = text + '{} of {}\n'.format(self.cards[i].rank , self.cards[i].suit)
        return text
    
    def shuffle(self):
        shuffle(self.cards)

# %%
class Player(Deck):
    def __init__(self,deck,playerNumber):
        if ( playerNumber == 1 ):
            self.cards = deck.cards[0:(int(len(deck.cards)/2))]
        
        elif ( playerNumber == 2 ):
            self.cards = deck.cards[(int(len(deck.cards)/2)):]
        
        self.subset = []
            
    def play_card(self):
        playcard = self.cards[0].value
        return playcard
        
    def take_card(self,deck):
        # Take the played card by the other player
        self.cards.append(deck.cards[0])
        
        # Take the subset of cards of the other player
        self.cards = self.cards + [ x for x in deck.subset ]
        
        # Take own player's subset of cards
        self.cards = self.cards + [ x for x in self.subset ]
        
        # Remove the played card by the other player
        deck.cards.pop(0)
        
        # Clear the subset of the other player
        deck.subset.clear()
        
        # Clear own player's subset of cards
        self.subset.clear()
        
    def war(self,playerNumber):
        if ( len(self.cards) > 3):
            self.subset = self.subset + [ x for x in self.cards[0:3] ]
            for i in [2,1,0]:
                self.cards.pop(i)
                
            return True
        
        else:
            print('Player {} does not have enough cards to play'.format(playerNumber))
            return False
            
    def print_subset(self):
        for i in range (len(self.subset)):
            print('{} of {}'.format(self.subset[i].rank,self.subset[i].suit))

# %%
def validateInput(word):

    if ( word.lower() == 'yes' ):
        return True
            
    elif ( word.lower() == 'no' ):
        return True
            
    else:
        return False

# %%
deck = Deck()

# %%
deck.shuffle()

# %%
player1 = Player(deck,1)

# %%
player2 = Player(deck,2)

# %%
game_on = True
value1 = True
value2 = True
turn = 1

while game_on:

    print('               TURN NUMBER {}              \n'.format(turn))
    print('   Player 1 draws a {} ({}) of {}'.format(player1.cards[0].rank,player1.cards[0].value,player1.cards[0].suit))
    print('   Player 2 draws a {} ({}) of {}\n'.format(player2.cards[0].rank,player2.cards[0].value,player2.cards[0].suit))

    if ( player1.play_card() > player2.play_card() ):
        print('==========Player 1 wins this turn==========\n')
        player1.take_card(player2)
        player1.print_subset()

    elif ( player1.play_card() < player2.play_card() ):
        print('==========Player 2 wins this turn==========\n')
        player2.take_card(player1)
        player2.print_subset()

    elif ( player1.play_card() == player2.play_card() ):
        print('====================War====================')
        
        value1 = player1.war(1)
        print('Player 1 subset')
        player1.print_subset()
        print('===========================================')
        
        value2 = player2.war(2)
        print('Player 2 subset')
        player2.print_subset()
        print('===========================================\n')
        
    player1.shuffle()
    player2.shuffle()
    
    if ( ( len(player1.cards) == 0 ) or ( len(player2.cards) == 0 ) or (value1 == False) or (value2 == False) ):
        game_on = False
        print('+-----------------------------------------+')
        if ( len(player1.cards) > len(player2.cards) ):
            print('|        Player 1 WINS THE GAME           |')
            
        else:
            print('|        Player 2 WINS THE GAME           |')
        print('+-----------------------------------------+\n')
        
        while True:
            word = input('Do you want to keep playing (yes/no): ')
            check = validateInput(word)
            
            if ( check ):
                deck = Deck()
                deck.shuffle()
                player1 = Player(deck,1)
                player2 = Player(deck,2)
                game_on = True
                value1 = True
                value2 = True
                turn = 1
                break
                
        if ( word.lower() == 'yes' ):
            continue
            
        elif ( word.lower() == 'no' ):
            print('Thanks for playing')
            break

    else:   
        print(' Player 1 has {} cards and {} on the subset'.format(len(player1.cards),len(player1.subset)))
        print(' Player 2 has {} cards and {} on the subset'.format(len(player2.cards),len(player2.subset)))
        print('----------------------------------------------\n')

    turn += 1
# Out:
#                TURN NUMBER 1
#
#    Player 1 draws a five (5) of clubs
#    Player 2 draws a four (4) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 2
#
#    Player 1 draws a jack (11) of spades
#    Player 2 draws a seven (7) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 28 cards and 0 on the subset
#  Player 2 has 24 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 3
#
#    Player 1 draws a three (3) of hearts
#    Player 2 draws a king (13) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 4
#
#    Player 1 draws a jack (11) of hearts
#    Player 2 draws a two (2) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 28 cards and 0 on the subset
#  Player 2 has 24 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 5
#
#    Player 1 draws a queen (12) of diamonds
#    Player 2 draws a three (3) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 29 cards and 0 on the subset
#  Player 2 has 23 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 6
#
#    Player 1 draws a queen (12) of hearts
#    Player 2 draws a ten (10) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 7
#
#    Player 1 draws a jack (11) of diamonds
#    Player 2 draws a six (6) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 8
#
#    Player 1 draws a five (5) of spades
#    Player 2 draws a eight (8) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 9
#
#    Player 1 draws a two (2) of diamonds
#    Player 2 draws a king (13) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 29 cards and 0 on the subset
#  Player 2 has 23 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 10
#
#    Player 1 draws a five (5) of hearts
#    Player 2 draws a eight (8) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 28 cards and 0 on the subset
#  Player 2 has 24 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 11
#
#    Player 1 draws a ten (10) of hearts
#    Player 2 draws a eight (8) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 29 cards and 0 on the subset
#  Player 2 has 23 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 12
#
#    Player 1 draws a jack (11) of hearts
#    Player 2 draws a ten (10) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 13
#
#    Player 1 draws a ten (10) of hearts
#    Player 2 draws a nine (9) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 14
#
#    Player 1 draws a king (13) of hearts
#    Player 2 draws a three (3) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 32 cards and 0 on the subset
#  Player 2 has 20 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 15
#
#    Player 1 draws a three (3) of clubs
#    Player 2 draws a nine (9) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 16
#
#    Player 1 draws a nine (9) of clubs
#    Player 2 draws a four (4) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 32 cards and 0 on the subset
#  Player 2 has 20 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 17
#
#    Player 1 draws a queen (12) of hearts
#    Player 2 draws a four (4) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 33 cards and 0 on the subset
#  Player 2 has 19 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 18
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a nine (9) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 34 cards and 0 on the subset
#  Player 2 has 18 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 19
#
#    Player 1 draws a seven (7) of hearts
#    Player 2 draws a seven (7) of spades
#
# ====================War====================
# Player 1 subset
# seven of hearts
# jack of hearts
# queen of clubs
# ===========================================
# Player 2 subset
# seven of spades
# king of clubs
# five of hearts
# ===========================================
#
#  Player 1 has 31 cards and 3 on the subset
#  Player 2 has 15 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 20
#
#    Player 1 draws a two (2) of clubs
#    Player 2 draws a five (5) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 21
#
#    Player 1 draws a jack (11) of clubs
#    Player 2 draws a seven (7) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 22
#
#    Player 1 draws a four (4) of diamonds
#    Player 2 draws a five (5) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 23
#
#    Player 1 draws a king (13) of diamonds
#    Player 2 draws a ten (10) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 24
#
#    Player 1 draws a eight (8) of clubs
#    Player 2 draws a ace (14) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 25
#
#    Player 1 draws a queen (12) of hearts
#    Player 2 draws a two (2) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 26
#
#    Player 1 draws a four (4) of clubs
#    Player 2 draws a five (5) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 27
#
#    Player 1 draws a four (4) of hearts
#    Player 2 draws a ace (14) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 29 cards and 0 on the subset
#  Player 2 has 23 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 28
#
#    Player 1 draws a queen (12) of spades
#    Player 2 draws a ace (14) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 28 cards and 0 on the subset
#  Player 2 has 24 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 29
#
#    Player 1 draws a ten (10) of diamonds
#    Player 2 draws a ace (14) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 30
#
#    Player 1 draws a seven (7) of diamonds
#    Player 2 draws a king (13) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 31
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a king (13) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 32
#
#    Player 1 draws a ten (10) of hearts
#    Player 2 draws a six (6) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 28 cards and 0 on the subset
#  Player 2 has 24 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 33
#
#    Player 1 draws a two (2) of hearts
#    Player 2 draws a five (5) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 34
#
#    Player 1 draws a ten (10) of hearts
#    Player 2 draws a eight (8) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 28 cards and 0 on the subset
#  Player 2 has 24 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 35
#
#    Player 1 draws a seven (7) of hearts
#    Player 2 draws a two (2) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 29 cards and 0 on the subset
#  Player 2 has 23 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 36
#
#    Player 1 draws a king (13) of diamonds
#    Player 2 draws a five (5) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 37
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a ten (10) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 38
#
#    Player 1 draws a ten (10) of diamonds
#    Player 2 draws a ace (14) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 39
#
#    Player 1 draws a eight (8) of diamonds
#    Player 2 draws a four (4) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 40
#
#    Player 1 draws a seven (7) of clubs
#    Player 2 draws a five (5) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 32 cards and 0 on the subset
#  Player 2 has 20 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 41
#
#    Player 1 draws a king (13) of spades
#    Player 2 draws a four (4) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 33 cards and 0 on the subset
#  Player 2 has 19 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 42
#
#    Player 1 draws a ten (10) of hearts
#    Player 2 draws a seven (7) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 34 cards and 0 on the subset
#  Player 2 has 18 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 43
#
#    Player 1 draws a three (3) of hearts
#    Player 2 draws a eight (8) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 33 cards and 0 on the subset
#  Player 2 has 19 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 44
#
#    Player 1 draws a nine (9) of diamonds
#    Player 2 draws a jack (11) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 32 cards and 0 on the subset
#  Player 2 has 20 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 45
#
#    Player 1 draws a two (2) of diamonds
#    Player 2 draws a four (4) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 46
#
#    Player 1 draws a five (5) of clubs
#    Player 2 draws a three (3) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 32 cards and 0 on the subset
#  Player 2 has 20 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 47
#
#    Player 1 draws a five (5) of diamonds
#    Player 2 draws a queen (12) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 48
#
#    Player 1 draws a nine (9) of hearts
#    Player 2 draws a five (5) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 32 cards and 0 on the subset
#  Player 2 has 20 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 49
#
#    Player 1 draws a queen (12) of diamonds
#    Player 2 draws a king (13) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 50
#
#    Player 1 draws a five (5) of hearts
#    Player 2 draws a three (3) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 32 cards and 0 on the subset
#  Player 2 has 20 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 51
#
#    Player 1 draws a seven (7) of clubs
#    Player 2 draws a ace (14) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 52
#
#    Player 1 draws a three (3) of hearts
#    Player 2 draws a seven (7) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 53
#
#    Player 1 draws a five (5) of diamonds
#    Player 2 draws a two (2) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 31 cards and 0 on the subset
#  Player 2 has 21 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 54
#
#    Player 1 draws a six (6) of spades
#    Player 2 draws a six (6) of hearts
#
# ====================War====================
# Player 1 subset
# six of spades
# jack of spades
# six of diamonds
# ===========================================
# Player 2 subset
# six of hearts
# eight of clubs
# nine of diamonds
# ===========================================
#
#  Player 1 has 28 cards and 3 on the subset
#  Player 2 has 18 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 55
#
#    Player 1 draws a seven (7) of hearts
#    Player 2 draws a ace (14) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 56
#
#    Player 1 draws a jack (11) of clubs
#    Player 2 draws a queen (12) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 57
#
#    Player 1 draws a nine (9) of spades
#    Player 2 draws a eight (8) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 58
#
#    Player 1 draws a two (2) of clubs
#    Player 2 draws a seven (7) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 59
#
#    Player 1 draws a king (13) of diamonds
#    Player 2 draws a four (4) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 60
#
#    Player 1 draws a four (4) of diamonds
#    Player 2 draws a queen (12) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 61
#
#    Player 1 draws a jack (11) of diamonds
#    Player 2 draws a three (3) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 62
#
#    Player 1 draws a king (13) of hearts
#    Player 2 draws a four (4) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 28 cards and 0 on the subset
#  Player 2 has 24 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 63
#
#    Player 1 draws a five (5) of hearts
#    Player 2 draws a seven (7) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 64
#
#    Player 1 draws a three (3) of spades
#    Player 2 draws a five (5) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 65
#
#    Player 1 draws a two (2) of spades
#    Player 2 draws a eight (8) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 25 cards and 0 on the subset
#  Player 2 has 27 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 66
#
#    Player 1 draws a two (2) of diamonds
#    Player 2 draws a three (3) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 24 cards and 0 on the subset
#  Player 2 has 28 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 67
#
#    Player 1 draws a three (3) of diamonds
#    Player 2 draws a three (3) of clubs
#
# ====================War====================
# Player 1 subset
# three of diamonds
# five of clubs
# eight of spades
# ===========================================
# Player 2 subset
# three of clubs
# three of spades
# six of spades
# ===========================================
#
#  Player 1 has 21 cards and 3 on the subset
#  Player 2 has 25 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 68
#
#    Player 1 draws a nine (9) of clubs
#    Player 2 draws a seven (7) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 28 cards and 0 on the subset
#  Player 2 has 24 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 69
#
#    Player 1 draws a ten (10) of spades
#    Player 2 draws a seven (7) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 29 cards and 0 on the subset
#  Player 2 has 23 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 70
#
#    Player 1 draws a king (13) of spades
#    Player 2 draws a seven (7) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 71
#
#    Player 1 draws a five (5) of clubs
#    Player 2 draws a queen (12) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 29 cards and 0 on the subset
#  Player 2 has 23 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 72
#
#    Player 1 draws a queen (12) of hearts
#    Player 2 draws a two (2) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 30 cards and 0 on the subset
#  Player 2 has 22 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 73
#
#    Player 1 draws a five (5) of diamonds
#    Player 2 draws a five (5) of hearts
#
# ====================War====================
# Player 1 subset
# five of diamonds
# nine of clubs
# seven of hearts
# ===========================================
# Player 2 subset
# five of hearts
# ace of clubs
# ace of spades
# ===========================================
#
#  Player 1 has 27 cards and 3 on the subset
#  Player 2 has 19 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 74
#
#    Player 1 draws a four (4) of diamonds
#    Player 2 draws a five (5) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 75
#
#    Player 1 draws a ten (10) of spades
#    Player 2 draws a seven (7) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 27 cards and 0 on the subset
#  Player 2 has 25 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 76
#
#    Player 1 draws a three (3) of spades
#    Player 2 draws a jack (11) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 77
#
#    Player 1 draws a eight (8) of hearts
#    Player 2 draws a jack (11) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 25 cards and 0 on the subset
#  Player 2 has 27 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 78
#
#    Player 1 draws a queen (12) of hearts
#    Player 2 draws a three (3) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 79
#
#    Player 1 draws a three (3) of clubs
#    Player 2 draws a nine (9) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 25 cards and 0 on the subset
#  Player 2 has 27 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 80
#
#    Player 1 draws a eight (8) of spades
#    Player 2 draws a two (2) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 81
#
#    Player 1 draws a three (3) of diamonds
#    Player 2 draws a jack (11) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 25 cards and 0 on the subset
#  Player 2 has 27 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 82
#
#    Player 1 draws a ten (10) of clubs
#    Player 2 draws a five (5) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 26 cards and 0 on the subset
#  Player 2 has 26 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 83
#
#    Player 1 draws a three (3) of hearts
#    Player 2 draws a queen (12) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 25 cards and 0 on the subset
#  Player 2 has 27 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 84
#
#    Player 1 draws a ten (10) of spades
#    Player 2 draws a jack (11) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 24 cards and 0 on the subset
#  Player 2 has 28 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 85
#
#    Player 1 draws a ten (10) of hearts
#    Player 2 draws a ace (14) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 23 cards and 0 on the subset
#  Player 2 has 29 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 86
#
#    Player 1 draws a jack (11) of diamonds
#    Player 2 draws a queen (12) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 22 cards and 0 on the subset
#  Player 2 has 30 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 87
#
#    Player 1 draws a eight (8) of spades
#    Player 2 draws a two (2) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 23 cards and 0 on the subset
#  Player 2 has 29 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 88
#
#    Player 1 draws a six (6) of clubs
#    Player 2 draws a five (5) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 24 cards and 0 on the subset
#  Player 2 has 28 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 89
#
#    Player 1 draws a two (2) of diamonds
#    Player 2 draws a five (5) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 23 cards and 0 on the subset
#  Player 2 has 29 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 90
#
#    Player 1 draws a queen (12) of hearts
#    Player 2 draws a ace (14) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 22 cards and 0 on the subset
#  Player 2 has 30 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 91
#
#    Player 1 draws a four (4) of clubs
#    Player 2 draws a jack (11) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 21 cards and 0 on the subset
#  Player 2 has 31 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 92
#
#    Player 1 draws a five (5) of spades
#    Player 2 draws a eight (8) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 20 cards and 0 on the subset
#  Player 2 has 32 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 93
#
#    Player 1 draws a seven (7) of spades
#    Player 2 draws a queen (12) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 19 cards and 0 on the subset
#  Player 2 has 33 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 94
#
#    Player 1 draws a six (6) of clubs
#    Player 2 draws a jack (11) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 18 cards and 0 on the subset
#  Player 2 has 34 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 95
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a three (3) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 19 cards and 0 on the subset
#  Player 2 has 33 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 96
#
#    Player 1 draws a eight (8) of spades
#    Player 2 draws a four (4) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 20 cards and 0 on the subset
#  Player 2 has 32 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 97
#
#    Player 1 draws a eight (8) of spades
#    Player 2 draws a six (6) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 21 cards and 0 on the subset
#  Player 2 has 31 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 98
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a four (4) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 22 cards and 0 on the subset
#  Player 2 has 30 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 99
#
#    Player 1 draws a eight (8) of diamonds
#    Player 2 draws a ace (14) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 21 cards and 0 on the subset
#  Player 2 has 31 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 100
#
#    Player 1 draws a ten (10) of clubs
#    Player 2 draws a six (6) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 22 cards and 0 on the subset
#  Player 2 has 30 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 101
#
#    Player 1 draws a two (2) of hearts
#    Player 2 draws a ten (10) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 21 cards and 0 on the subset
#  Player 2 has 31 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 102
#
#    Player 1 draws a king (13) of hearts
#    Player 2 draws a seven (7) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 22 cards and 0 on the subset
#  Player 2 has 30 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 103
#
#    Player 1 draws a seven (7) of clubs
#    Player 2 draws a eight (8) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 21 cards and 0 on the subset
#  Player 2 has 31 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 104
#
#    Player 1 draws a ten (10) of clubs
#    Player 2 draws a queen (12) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 20 cards and 0 on the subset
#  Player 2 has 32 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 105
#
#    Player 1 draws a six (6) of diamonds
#    Player 2 draws a ace (14) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 19 cards and 0 on the subset
#  Player 2 has 33 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 106
#
#    Player 1 draws a six (6) of spades
#    Player 2 draws a six (6) of diamonds
#
# ====================War====================
# Player 1 subset
# six of spades
# seven of diamonds
# four of hearts
# ===========================================
# Player 2 subset
# six of diamonds
# seven of clubs
# queen of diamonds
# ===========================================
#
#  Player 1 has 16 cards and 3 on the subset
#  Player 2 has 30 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 107
#
#    Player 1 draws a six (6) of clubs
#    Player 2 draws a jack (11) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 15 cards and 0 on the subset
#  Player 2 has 37 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 108
#
#    Player 1 draws a five (5) of clubs
#    Player 2 draws a eight (8) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 14 cards and 0 on the subset
#  Player 2 has 38 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 109
#
#    Player 1 draws a four (4) of clubs
#    Player 2 draws a ten (10) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 13 cards and 0 on the subset
#  Player 2 has 39 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 110
#
#    Player 1 draws a king (13) of hearts
#    Player 2 draws a king (13) of clubs
#
# ====================War====================
# Player 1 subset
# king of hearts
# eight of spades
# two of clubs
# ===========================================
# Player 2 subset
# king of clubs
# two of spades
# ace of hearts
# ===========================================
#
#  Player 1 has 10 cards and 3 on the subset
#  Player 2 has 36 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 111
#
#    Player 1 draws a seven (7) of hearts
#    Player 2 draws a queen (12) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 112
#
#    Player 1 draws a nine (9) of spades
#    Player 2 draws a king (13) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 8 cards and 0 on the subset
#  Player 2 has 44 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 113
#
#    Player 1 draws a four (4) of spades
#    Player 2 draws a ace (14) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 7 cards and 0 on the subset
#  Player 2 has 45 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 114
#
#    Player 1 draws a king (13) of spades
#    Player 2 draws a jack (11) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 8 cards and 0 on the subset
#  Player 2 has 44 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 115
#
#    Player 1 draws a jack (11) of diamonds
#    Player 2 draws a five (5) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 116
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a jack (11) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 10 cards and 0 on the subset
#  Player 2 has 42 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 117
#
#    Player 1 draws a king (13) of diamonds
#    Player 2 draws a four (4) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 11 cards and 0 on the subset
#  Player 2 has 41 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 118
#
#    Player 1 draws a four (4) of diamonds
#    Player 2 draws a two (2) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 12 cards and 0 on the subset
#  Player 2 has 40 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 119
#
#    Player 1 draws a jack (11) of diamonds
#    Player 2 draws a jack (11) of hearts
#
# ====================War====================
# Player 1 subset
# jack of diamonds
# king of diamonds
# three of spades
# ===========================================
# Player 2 subset
# jack of hearts
# five of clubs
# jack of spades
# ===========================================
#
#  Player 1 has 9 cards and 3 on the subset
#  Player 2 has 37 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 120
#
#    Player 1 draws a king (13) of spades
#    Player 2 draws a three (3) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 16 cards and 0 on the subset
#  Player 2 has 36 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 121
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a nine (9) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 17 cards and 0 on the subset
#  Player 2 has 35 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 122
#
#    Player 1 draws a jack (11) of hearts
#    Player 2 draws a six (6) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 18 cards and 0 on the subset
#  Player 2 has 34 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 123
#
#    Player 1 draws a nine (9) of diamonds
#    Player 2 draws a eight (8) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 19 cards and 0 on the subset
#  Player 2 has 33 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 124
#
#    Player 1 draws a eight (8) of spades
#    Player 2 draws a two (2) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 20 cards and 0 on the subset
#  Player 2 has 32 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 125
#
#    Player 1 draws a three (3) of spades
#    Player 2 draws a king (13) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 19 cards and 0 on the subset
#  Player 2 has 33 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 126
#
#    Player 1 draws a jack (11) of hearts
#    Player 2 draws a two (2) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 20 cards and 0 on the subset
#  Player 2 has 32 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 127
#
#    Player 1 draws a three (3) of diamonds
#    Player 2 draws a three (3) of clubs
#
# ====================War====================
# Player 1 subset
# three of diamonds
# jack of hearts
# six of diamonds
# ===========================================
# Player 2 subset
# three of clubs
# eight of hearts
# nine of spades
# ===========================================
#
#  Player 1 has 17 cards and 3 on the subset
#  Player 2 has 29 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 128
#
#    Player 1 draws a nine (9) of hearts
#    Player 2 draws a ten (10) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 16 cards and 0 on the subset
#  Player 2 has 36 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 129
#
#    Player 1 draws a two (2) of clubs
#    Player 2 draws a six (6) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 15 cards and 0 on the subset
#  Player 2 has 37 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 130
#
#    Player 1 draws a five (5) of clubs
#    Player 2 draws a three (3) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 16 cards and 0 on the subset
#  Player 2 has 36 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 131
#
#    Player 1 draws a jack (11) of diamonds
#    Player 2 draws a king (13) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 15 cards and 0 on the subset
#  Player 2 has 37 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 132
#
#    Player 1 draws a seven (7) of spades
#    Player 2 draws a five (5) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 16 cards and 0 on the subset
#  Player 2 has 36 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 133
#
#    Player 1 draws a jack (11) of clubs
#    Player 2 draws a jack (11) of diamonds
#
# ====================War====================
# Player 1 subset
# jack of clubs
# nine of diamonds
# king of diamonds
# ===========================================
# Player 2 subset
# jack of diamonds
# six of diamonds
# three of hearts
# ===========================================
#
#  Player 1 has 13 cards and 3 on the subset
#  Player 2 has 33 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 134
#
#    Player 1 draws a five (5) of diamonds
#    Player 2 draws a eight (8) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 12 cards and 0 on the subset
#  Player 2 has 40 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 135
#
#    Player 1 draws a eight (8) of spades
#    Player 2 draws a nine (9) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 11 cards and 0 on the subset
#  Player 2 has 41 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 136
#
#    Player 1 draws a four (4) of spades
#    Player 2 draws a queen (12) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 10 cards and 0 on the subset
#  Player 2 has 42 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 137
#
#    Player 1 draws a king (13) of spades
#    Player 2 draws a ace (14) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 138
#
#    Player 1 draws a two (2) of spades
#    Player 2 draws a ten (10) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 8 cards and 0 on the subset
#  Player 2 has 44 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 139
#
#    Player 1 draws a five (5) of clubs
#    Player 2 draws a four (4) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 140
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a jack (11) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 10 cards and 0 on the subset
#  Player 2 has 42 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 141
#
#    Player 1 draws a two (2) of hearts
#    Player 2 draws a jack (11) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 142
#
#    Player 1 draws a four (4) of diamonds
#    Player 2 draws a ten (10) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 8 cards and 0 on the subset
#  Player 2 has 44 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 143
#
#    Player 1 draws a jack (11) of hearts
#    Player 2 draws a six (6) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 144
#
#    Player 1 draws a jack (11) of hearts
#    Player 2 draws a two (2) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 10 cards and 0 on the subset
#  Player 2 has 42 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 145
#
#    Player 1 draws a four (4) of spades
#    Player 2 draws a three (3) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 11 cards and 0 on the subset
#  Player 2 has 41 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 146
#
#    Player 1 draws a three (3) of diamonds
#    Player 2 draws a six (6) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 10 cards and 0 on the subset
#  Player 2 has 42 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 147
#
#    Player 1 draws a three (3) of spades
#    Player 2 draws a jack (11) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 148
#
#    Player 1 draws a four (4) of spades
#    Player 2 draws a six (6) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 8 cards and 0 on the subset
#  Player 2 has 44 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 149
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a two (2) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 150
#
#    Player 1 draws a jack (11) of spades
#    Player 2 draws a ten (10) of clubs
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 10 cards and 0 on the subset
#  Player 2 has 42 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 151
#
#    Player 1 draws a seven (7) of spades
#    Player 2 draws a three (3) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 11 cards and 0 on the subset
#  Player 2 has 41 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 152
#
#    Player 1 draws a jack (11) of spades
#    Player 2 draws a nine (9) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 12 cards and 0 on the subset
#  Player 2 has 40 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 153
#
#    Player 1 draws a ten (10) of clubs
#    Player 2 draws a five (5) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 13 cards and 0 on the subset
#  Player 2 has 39 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 154
#
#    Player 1 draws a jack (11) of hearts
#    Player 2 draws a ten (10) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 14 cards and 0 on the subset
#  Player 2 has 38 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 155
#
#    Player 1 draws a two (2) of spades
#    Player 2 draws a three (3) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 13 cards and 0 on the subset
#  Player 2 has 39 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 156
#
#    Player 1 draws a jack (11) of hearts
#    Player 2 draws a king (13) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 12 cards and 0 on the subset
#  Player 2 has 40 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 157
#
#    Player 1 draws a seven (7) of spades
#    Player 2 draws a eight (8) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 11 cards and 0 on the subset
#  Player 2 has 41 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 158
#
#    Player 1 draws a ten (10) of clubs
#    Player 2 draws a ten (10) of hearts
#
# ====================War====================
# Player 1 subset
# ten of clubs
# ten of spades
# three of hearts
# ===========================================
# Player 2 subset
# ten of hearts
# ace of hearts
# queen of spades
# ===========================================
#
#  Player 1 has 8 cards and 3 on the subset
#  Player 2 has 38 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 159
#
#    Player 1 draws a five (5) of clubs
#    Player 2 draws a jack (11) of clubs
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 7 cards and 0 on the subset
#  Player 2 has 45 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 160
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a ten (10) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 8 cards and 0 on the subset
#  Player 2 has 44 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 161
#
#    Player 1 draws a ace (14) of diamonds
#    Player 2 draws a ten (10) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 9 cards and 0 on the subset
#  Player 2 has 43 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 162
#
#    Player 1 draws a six (6) of diamonds
#    Player 2 draws a six (6) of clubs
#
# ====================War====================
# Player 1 subset
# six of diamonds
# ace of diamonds
# five of diamonds
# ===========================================
# Player 2 subset
# six of clubs
# ten of clubs
# nine of hearts
# ===========================================
#
#  Player 1 has 6 cards and 3 on the subset
#  Player 2 has 40 cards and 3 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 163
#
#    Player 1 draws a two (2) of diamonds
#    Player 2 draws a two (2) of clubs
#
# ====================War====================
# Player 1 subset
# six of diamonds
# ace of diamonds
# five of diamonds
# two of diamonds
# jack of spades
# ten of diamonds
# ===========================================
# Player 2 subset
# six of clubs
# ten of clubs
# nine of hearts
# two of clubs
# eight of spades
# four of spades
# ===========================================
#
#  Player 1 has 3 cards and 6 on the subset
#  Player 2 has 37 cards and 6 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 164
#
#    Player 1 draws a five (5) of hearts
#    Player 2 draws a ace (14) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 2 cards and 0 on the subset
#  Player 2 has 50 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 165
#
#    Player 1 draws a ten (10) of spades
#    Player 2 draws a nine (9) of diamonds
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 3 cards and 0 on the subset
#  Player 2 has 49 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 166
#
#    Player 1 draws a ten (10) of spades
#    Player 2 draws a three (3) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 4 cards and 0 on the subset
#  Player 2 has 48 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 167
#
#    Player 1 draws a three (3) of spades
#    Player 2 draws a eight (8) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 3 cards and 0 on the subset
#  Player 2 has 49 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 168
#
#    Player 1 draws a nine (9) of spades
#    Player 2 draws a king (13) of diamonds
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 2 cards and 0 on the subset
#  Player 2 has 50 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 169
#
#    Player 1 draws a nine (9) of diamonds
#    Player 2 draws a eight (8) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 3 cards and 0 on the subset
#  Player 2 has 49 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 170
#
#    Player 1 draws a nine (9) of diamonds
#    Player 2 draws a five (5) of hearts
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 4 cards and 0 on the subset
#  Player 2 has 48 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 171
#
#    Player 1 draws a nine (9) of diamonds
#    Player 2 draws a three (3) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 5 cards and 0 on the subset
#  Player 2 has 47 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 172
#
#    Player 1 draws a ten (10) of spades
#    Player 2 draws a ace (14) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 4 cards and 0 on the subset
#  Player 2 has 48 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 173
#
#    Player 1 draws a five (5) of hearts
#    Player 2 draws a queen (12) of hearts
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 3 cards and 0 on the subset
#  Player 2 has 49 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 174
#
#    Player 1 draws a three (3) of spades
#    Player 2 draws a ace (14) of spades
#
# ==========Player 2 wins this turn==========
#
#  Player 1 has 2 cards and 0 on the subset
#  Player 2 has 50 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 175
#
#    Player 1 draws a nine (9) of diamonds
#    Player 2 draws a two (2) of spades
#
# ==========Player 1 wins this turn==========
#
#  Player 1 has 3 cards and 0 on the subset
#  Player 2 has 49 cards and 0 on the subset
# ----------------------------------------------
#
#                TURN NUMBER 176
#
#    Player 1 draws a eight (8) of spades
#    Player 2 draws a eight (8) of diamonds
#
# ====================War====================
# Player 1 does not have enough cards to play
# Player 1 subset
# ===========================================
# Player 2 subset
# eight of diamonds
# three of hearts
# six of hearts
# ===========================================
#
# +-----------------------------------------+
# |        Player 2 WINS THE GAME           |
# +-----------------------------------------+
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3896\1953673862.py in <module>
#      47
#      48         while True:
# ---> 49             word = input('Do you want to keep playing (yes/no): ')
#      50             check = validateInput(word)
#      51
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
